# %% [markdown]
# #Priemier League Standings Single Season
#
# ### This is for testing purposes

# %%
import os
import json
import requests
import pandas as pd
from mysql import connector 
from dotenv import load_dotenv

# %%
load_dotenv{}
